# %% [markdown]
# <a href="https://colab.research.google.com/github/coderkartikeya/ml-learning/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ax=plt.subplot()
ax.plot([1,2,3,4],[2,4,5,8])
plt.show()
